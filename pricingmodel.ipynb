# %% [markdown]
# ## Modified Model
#
# $$
# \begin{align*}
#     Max\ \ \ \ \  \underset{(i,j)\in E \ if \ j \neq i } \ {\Sigma} \underset{h\in H}{\Sigma} \ (p_{ij}^h d2_{i}-c_{ij}^h d_{ij} ) \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; (1)\\
# \end{align*}
# $$
# s.t.
#
# $$
# \begin{align*}
#          p_{ij}^h \leq WTP_i /d2_i+(1-x_{ij}^h)M \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall h \in H, \ \forall i \in A, \ \forall j \in {A \cup A'} \ (if \ i \neq j) \; \; \; \; \; \; (2) \\
# \end{align*}
# $$
#
# $$
# \begin{align*}
#          c_{ij}^h \geq ETP_h x_{ij}^h \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \forall h \in H, \ \forall i \in {\tau_h \cup A \cup A'}, \  \forall j \in A \cup A' \ (if \ i \neq j) \; \; \; \; \; \; (3) \\
# \end{align*}
# $$
#
# $$
# \begin{align*}
#          p_{ij}^h \geq c_{ij}^h \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \forall h \in H, \ \forall i \in A, \  \forall j \in A \cup A' \ (if \ i \neq j)   \; \; \; \; \; \; (4) \\
# \end{align*}
# $$
#
# $$
# \begin{align*}
#        \sum_{h \in H}  \sum_{j \in A'} x^{h}_{ij}+ z_i = 1 \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall i \in A \ \ \hfill  \; \; \; \; \; \; (5) \\
# \end{align*}
# $$
#
# $$
# \begin{align*}
#        \sum_{j \in V} x^{h}_{ij} - \sum_{j \in V}x^{h}_{j,n+i}=0 \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \forall h \in H \ \ \hfill  \; \; \; \; \; \; (6) \\
# \end{align*}
# $$
#
# $$
# \begin{align*}
#        \sum_{j \in A \cup \tau_h'} x^{h}_{\tau_hj} =1 \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall h \in H \ \ \hfill  \; \; \; \; \; \; (7) \\
# \end{align*}
# $$
#
# $$
# \begin{align*}
#        \sum_{i \in A' \cup \tau_h} x^{h}_{i\tau_h'} =, \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall h \in H \ \ \hfill  \; \; \; \; \; \; (8) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        \sum_{i \in V} x^{h}_{ij} - \sum_{i \in V} x^{h}_{ji} =0 \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall j \in A', \forall h \in H \ \ \hfill \; \; \; \; \; \;  (9) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        S_{i}^h + s_i + t_{ij} \leq S_j^h + (1 - x^{h}_{ij})M \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall (i,j) \in E, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (10) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        a_{i} \leq S_i^h \leq b_i \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall i \in V, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (11) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        S_{i}^h \leq S_{n+i}^h \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall i \in V, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (12) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        L_{i}^h + l_j \leq L_j^h + (1 - x_{ij}^h)M \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall (i,j) \in E, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (13) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        L_{i}^h \leq R^h \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall i \in V, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (14) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        L_{\tau_h}^h = L_{\tau_h'}^h =0 \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;   \forall h \in H \ \ \hfill \; \; \; \; \; \;  (15) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        p_{ij}^h \leq M x_{ij}^h \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;    \ \ \hfill \; \; \; \; \; \;  (16) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        c_{ij} \leq M x_{ij}^h \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;    \ \ \hfill \; \; \; \; \; \;  (17) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        p_i x_{ij}^h =  p_i \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;    \ \ \hfill \; \; \; \; \; \;  (18) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        c_{ij} x_{ij}^h =  c_{ij} \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;    \ \ \hfill \; \; \; \; \; \;  (19) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        x_{i,j}^h \in \{0,1\} \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall (i,j) \in E, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (20) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        z_i \in \{0,1\} \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall i \in A \ \ \hfill \; \; \; \; \; \;  (21) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        S_i^h \geq 0  \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall i \in V, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (22) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        L_i^h, R^h \geq 0  \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \forall i \in V, \forall h \in H \ \ \hfill \; \; \; \; \; \;  (23) \\
# \end{align*}
# $$
# $$
# \begin{align*}
#        p_i, c_{ij} \geq 0  \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \; \;  \ \ \hfill \; \; \; \; \; \;  (24) \\
# \end{align*}
# $$

# %% [markdown]
# $(1)$ $ \to $ $d2_i$ is a new parameter: as $d_{ij}$ with $ (ij) \in E $ refers to all links possible, we can use only certain links for the objective function to calculate the income - $d_i$ with $i \in A$: only the links starting in pick up tasks - the platform does not get any money for e.g. ODs driving from origin to destination
